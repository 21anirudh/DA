# %% [markdown]
# <a href="https://colab.research.google.com/github/21anirudh/DA/blob/main/ML/Regression/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data Points
x = np.array([5, 7, 8, 7, 2])
y = np.array([9, 8, 7, 8, 11])

# Number of data points
n =len(x)

# %% [markdown]
# # SLR using Least Squares Method

# %%
# Calculate sums required for least squares method
sum_x = np.sum(x)
sum_y = np.sum(y)
sum_sy = np.sum(x*y)
sum_x_squared = np.sum(x**2)

# Calculate slope (m) and y-intercept (c)
m = (n*sum_sy - sum_x*sum_y) / (n*sum_x_squared - sum_x**2)
c = (sum_y - m*sum_x) / n

print(f"Slope (m): {m}")
print(f"y-Intercept (c): {c}")

# Plotting the data points
plt.scatter(x, y, color='blue', label='Data Points')

# Plotting the regression line
plt.plot(x, m*x + c, color='red', label=f'Regression Line: y = {n:.2f}x + {c:.2f}')

# Adding labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Simple Linear Regression using Least Squares Method')

# Adding a legend
plt.legend()

# Display the plot
plt.show()
# Out:
# Slope (m): -0.631578947368421
# y-Intercept (c): 12.26315789473684

# %% [markdown]
# # SLR using Gradient Descent Method

# %%
# Hyperparameters required for gradient descent method
learning_rate = 0.05
epochs = 200 # Number of iterations

# Initialize m (slope) and c (intercept) to zero
m = 0
c = 0

# Store history of m and c for plotting
m_history = [m]
c_history = [c]

# Gradient Descent Function
for epoch in range(epochs):
    # Calculate predicted values
    y_pred = m * x + c

    # Calculate the gradients
    dm = (-2/n) * np.sum(x * (y - y_pred))
    dc = (-2/n) * np.sum(y - y_pred)

    # Update m and c
    m -= learning_rate * dm
    c -= learning_rate * dc

    # Update parameters
    m -= learning_rate * dm
    c -= learning_rate * dc

    # Store updated parameters
    m_history.append(m)
    c_history.append(c)

    # Print values every 20 epochs
    if (epoch + 1) % 20 == 0:
        print(f"Epoch {epoch + 1}: m = {m:.4f}, c = {c:.4f}")

# Plotting the data points
plt.scatter(x, y, color='blue', label='Data Points')

# Plotting the regression line
plt.plot(x, m * x + c, color='red', label=f'Regression Line: y = {m:.2f}x + {c:.2f}')

# Labeling the axes
plt.xlabel('x')
plt.ylabel('y')
plt.title('Simple Linear Regression using Gradient Descent Method')

# Adding a legend
plt.legend()

# Display the plot
plt.show()
# Out:
# Epoch 20: m = -56692351270708744.0000, c = -8634110256085069.0000
# Epoch 40: m = -2660503319865682616907414389129216.0000, c = -405188327623115215527268925308928.0000
# Epoch 60: m = -124854195607749634249528619394957533615805979164672.0000, c = -19014997026046728003810460330954209252108557877248.0000
# Epoch 80: m = -5859256045448272961890106656612861896191831568177373168966238732288.0000, c = -892350759513681675759119720217733264861933982369826244916376764416.0000
# Epoch 100: m = -274967783333275791465366791756601920378134075830229829775026225332591034445225525248.0000, c = -41876939392306395882778541656105608622777606652980421831414368756019583139352412160.0000
# Epoch 120: m = -12903904742300908218880892540838268795021234504445083283403779260647562735906316920201685613703856128.0000, c = -1965234000386384245833305909568181753370553805470541399264753230767258946929217246488982861471809536.0000
# ...
